# %% [markdown]
# # Chapter 02 파이토치 시작하기

# %% [markdown]
# ## 코랩 사용법

# %% [markdown]
# 파일 업로드 하기

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3e2574f-06b4-4350-9283-79ce1dd901d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3e2574f-06b4-4350-9283-79ce1dd901d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %% [markdown]
# 파일 업로드 됐는지 확인

# %%
# !ls
# Out:
# sample_data  train.csv

# %% [markdown]
# 정상적으로 데이터 로딩되는지 확인

# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv("train.csv")

print(dataset)

print(dataset.to_numpy())
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]
# [[1 0 3 ... 7.25 nan 'S']
#  [2 1 1 ... 71.2833 'C85' 'C']
#  [3 1 3 ... 7.925 nan 'S']
#  ...
#  [889 0 3 ... 23.45 nan 'S']
#  [890 1 1 ... 30.0 'C148' 'C']
#  [891 0 3 ... 7.75 nan 'Q']]

# %% [markdown]
# 구글 드라이브 연동하기
# * 특정 파일을 계속 사용할 경우 구글 드라이브에 파일을 업로드 한 후에 연동하는게 좋음

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# 구글 드라이브 파일 목록 확인

# %%
# !ls "/gdrive/My Drive"
# Out:
#  자료구조	    Dacon				   Kaggle
#  혼공머		    data				   mathematics
#  3-min-pytorch	    DL_from_bottom			   opencv
#  baekjoon	    hands_on				   programmers
# 'Colab Notebooks'   데이터멘토링_지원신청서_데.분.수.hwp   result.json

# %% [markdown]
# 구글 드라이브 내 파일 읽기

# %%
dataset = pd.read_csv("/gdrive/MyDrive/data/Titanic/train.csv")

print(dataset)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
import os, sys
os.chdir('/gdrive/MyDrive')
sys.path.append(os.chdir)

# %%
# !ls
# Out:
#  자료구조	    Dacon				   Kaggle
#  혼공머		    data				   mathematics
#  3-min-pytorch	    DL_from_bottom			   opencv
#  baekjoon	    hands_on				   programmers
# 'Colab Notebooks'   데이터멘토링_지원신청서_데.분.수.hwp   result.json
